# %% [markdown]
# ## Семинар 1 Индекс
#
# ## Intro

# %% [markdown]
# ### работа с файлами и папками

# %%
import os

curr_dir = os.getcwd()
filepath = os.path.join(curr_dir, 'test.txt')

# %% [markdown]
# ### os.path
# путь до файла

# %%
# возвращает полный путь до папки/файла по имени файла / папки
print(os.path.abspath(filepath))


# возвращает имя файла / папки по полному ти до него
print(os.path.basename(filepath))


# проверить существование директории - True / False
print(os.path.exists(curr_dir))
# Out:
# C:\Users\Eduard\Desktop\Projects\infosearch\test.txt
# test.txt
# True

# %% [markdown]
# ### os.listdir
# возвращает список файлов в данной директории

# %%
os.listdir(curr_dir)
# Out:
# ['.ipynb_checkpoints',
#  'friends',
#  'inverted_collection_without_stopwords.json',
#  'inverted_collection_with_stopwords.json',
#  'sem1_Index.ipynb',
#  'test.txt']

# %% [markdown]
# При обходе файлов не забывайте исключать системные директории, такие как .DS_Store

# %% [markdown]
# ### os.walk
# root - начальная директория
# dirs - список поддиректорий (папок)
# files - список файлов в этих поддиректориях

# %%
for root, dirs, files in os.walk(curr_dir):
    for name in files:
        print(os.path.join(root, name))
# Out:
# C:\Users\Eduard\Desktop\Projects\infosearch\inverted_collection_without_stopwords.json
# C:\Users\Eduard\Desktop\Projects\infosearch\inverted_collection_with_stopwords.json
# C:\Users\Eduard\Desktop\Projects\infosearch\sem1_Index.ipynb
# C:\Users\Eduard\Desktop\Projects\infosearch\test.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\.ipynb_checkpoints\sem1_Index-checkpoint.ipynb
# C:\Users\Eduard\Desktop\Projects\infosearch\.ipynb_checkpoints\sem_texts_Grigorev-checkpoint.ipynb
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x01 - The One Where Monica Gets A Roommate.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x02 - The One With The Sonogram At The End.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x03 - The One With The Thumb.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x04 - The One With George Stephanopoulos.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x05 - The One With The East German Laundry Detergent.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x06 - The One With The Butt.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x07 - The One With The Blackout.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x08 - The One Where Nana Dies Twice.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x09 - The One Where Underdog Gets Away.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x10 - The One With The Monkey.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x11 - The One With Mrs. Bing.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x12 - The One With The Dozen Lasagnas.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x13 - The One With The Boobies.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x14 - The One With The Candy Hearts.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x15 - The One With The Stoned Guy.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x16 - The One With Two Parts (1).ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x17 - The One With Two Parts (2).ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x18 - The One With All The Poker.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x19 - The One Where The Monkey Gets Away.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 1\Friends - 1x20 - The One With The Evil Orthodontist.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x01 - The One With Ross's New Girlfriend.DVDRip.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x01 - The One With Ross's New Girlfriend.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x02 - The One With The Breast Milk.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x03 - The One Where Heckles Dies.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x04 - The One With Phoebe's Husband.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x05 - The One With Five Steaks And An Eggplant.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x06 - The One With The Baby On The Bus.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 2\Friends - 2x07 - The One Where Ross Finds Out.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season
ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x05 - The One With The Engagement Picture.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x06 - The One With The Nap Partners.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x07 - The One With Ross's Library Book.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x08 - The One Where Chandler Doesn't Like Dogs.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x09 - The One With All The Candy.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x10 - The One With The Holiday Armadillo.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x11 - The One With All The Cheesecakes.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x12 - The One Where They're Up All Night.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x13 - The One Where Rosita Dies.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x14 - The One Where They All Turn Thirty.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x15 - The One With Joey's New Brain.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x16 - The One With The Truth About London.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x18 - The One With Joey's Award.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x20 - The One With Rachel's Big Kiss.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x21 - The One With The Vows.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x22 - The One With Chandler's Dad.ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt
# C:\Users\Eduard\Desktop\Projects\infosearch\friends\Friends - season 7\Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt

# %% [markdown]
# > __os.walk__ возвращает генератор, это значит, что получить его элементы можно только проитерировавшись по нему
# но его легко можно превратить в list и увидеть все его значения

# %%
list(os.walk(curr_dir))
# Out:
# [('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch',
#   ['.ipynb_checkpoints', 'friends'],
#   ['inverted_collection_without_stopwords.json',
#    'inverted_collection_with_stopwords.json',
#    'sem1_Index.ipynb',
#    'test.txt']),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\.ipynb_checkpoints',
#   [],
#   ['sem1_Index-checkpoint.ipynb', 'sem_texts_Grigorev-checkpoint.ipynb']),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends',
#   ['Friends - season 1',
#    'Friends - season 2',
#    'Friends - season 3',
#    'Friends - season 4',
#    'Friends - season 5',
#    'Friends - season 6',
#    'Friends - season 7'],
#   []),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 1',
#   [],
#   ['Friends - 1x01 - The One Where Monica Gets A Roommate.ru.txt',
#    'Friends - 1x02 - The One With The Sonogram At The End.ru.txt',
#    'Friends - 1x03 - The One With The Thumb.ru.txt',
#    'Friends - 1x04 - The One With George Stephanopoulos.ru.txt',
#    'Friends - 1x05 - The One With The East German Laundry Detergent.ru.txt',
#    'Friends - 1x06 - The One With The Butt.ru.txt',
#    'Friends - 1x07 - The One With The Blackout.ru.txt',
#    'Friends - 1x08 - The One Where Nana Dies Twice.ru.txt',
#    'Friends - 1x09 - The One Where Underdog Gets Away.ru.txt',
#    'Friends - 1x10 - The One With The Monkey.ru.txt',
#    'Friends - 1x11 - The One With Mrs. Bing.ru.txt',
#    'Friends - 1x12 - The One With The Dozen Lasagnas.ru.txt',
#    'Friends - 1x13 - The One With The Boobies.ru.txt',
#    'Friends - 1x14 - The One With The Candy Hearts.ru.txt',
#    'Friends - 1x15 - The One With The Stoned Guy.ru.txt',
#    'Friends - 1x16 - The One With Two Parts (1).ru.txt',
#    'Friends - 1x17 - The One With Two Parts (2).ru.txt',
#    'Friends - 1x18 - The One With All The Poker.ru.txt',
#    'Friends - 1x19 - The One Where The Monkey Gets Away.ru.txt',
#    'Friends - 1x20 - The One With The Evil Orthodontist.ru.txt']),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 2',
#   [],
#   ["Friends - 2x01 - The One With Ross's New Girlfriend.DVDRip.ru.txt",
#    "Friends - 2x01 - The One With Ross's New Girlfriend.ru.txt",
#    'Friends - 2x02 - The One With The Breast Milk.ru.txt',
#    'Friends - 2x03 - The One Where Heckles Dies.ru.txt',
#    "Friends - 2x04 - The One With Phoebe's Husband.ru.txt",
#    'Friends - 2x05 - The One With Five Steaks And An Eggplant.ru.txt',
#    'Friends - 2x06 - The One With The Baby On The Bus.ru.txt',
#    'Friends - 2x07 - The One Where Ross Finds Out.ru.txt',
#    'Friends - 2x08 - The One With The List.ru.txt',
#    "Friends - 2x09 - The One With Phoebe's Dad.ru.txt",
#    'Friends - 2x10 - The One With Russ.ru.txt',
#    'Friends - 2x11 - The One With The Lesbian Wedding.ru.txt',
#    'Friends - 2x12 - The One After The Super Bowl (1).ru.txt',
#    'Friends - 2x13 - The One After The Super Bowl (2).ru.txt',
#    'Friends - 2x14 - The One With The Prom Video.ru.txt',
#    'Friends - 2x15 - The One Where Ross And Rachel...You Know.ru.txt',
#    'Friends - 2x16 - The One Where Joey Moves Out.ru.txt',
#    'Friends - 2x17 - The One Where Eddie Moves In.ru.txt',
#    'Friends - 2x18 - The One Where Dr. Ramoray Dies.ru.txt',
#    "Friends - 2x19 - The One Where Eddie Won't Go.ru.txt",
#    'Friends - 2x20 - The One Where Old Yeller Dies.NurlanB.ru.txt',
#    'Friends - 2x21 - The One With The Bullies.ru.txt',
#    'Friends - 2x22 - The One With The Two Parties.ru.txt',
#    'Friends - 2x23 - The One With The Chicken Pox.ru.txt',
#    "Friends - 2x24 - The One With Barry And Mindy's Wedding.ru.txt"]),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 3',
#   [],
#   ['Friends - 3x01 - The One With The Princess Leia Fantasy.ru.txt',
#    "Friends - 3x02 - The One Where No One's Ready.ru.txt",
#    'Friends - 3x03 - The One With The Jam.ru.txt',
#    'Friends - 3x04 - The One With The Metaphorical Tunnel.ru.txt',
#    'Friends - 3x05 - The One With Frank Jr..ru.txt',
#    'Friends - 3x06 - The One With The Flashback.ru.txt',
#    'Friends - 3x07 - The One With The Race Car Bed.ru.txt',
#    'Friends - 3x08 - The One With The Giant Poking Device.ru.txt',
#    'Friends - 3x09 - The One With The Football.ru.txt',
#    'Friends - 3x10 - The One Where Rachel Quits.ru.txt',
#    "Friends - 3x11 - The One Where Chandler Can't Remember Which Sister.ru.txt",
#    'Friends - 3x12 - The One With All The Jealousy.ru.txt',
#    'Friends - 3x13 - The One Where Monica And Richard Are Just Friends.ru.txt',
#    "Friends - 3x14 - The One With Phoebe's Ex-Partner.ru.txt",
#    'Friends - 3x15 - The One Where Ross And Rachel Take A Break (1).ru.txt',
#    'Friends - 3x16 - The One With The Morning After (2).ru.txt',
#    'Friends - 3x17 - The One Without The Ski Trip.ru.txt',
#    'Friends - 3x18 - The One With The Hypnosis Tape.ru.txt',
#    'Friends - 3x19 - The One With The Tiny T-Shirt.ru.txt',
#    'Friends - 3x20 - The One With The Dollhouse.ru.txt',
#    'Friends - 3x21 - The One With A Chick And A Duck.ru.txt']),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 4',
#   [],
#   ['Friends - 4x01 - The One With The Jellyfish.ru.txt',
#    'Friends - 4x01 - The One With The Jellyfish.Tv.ru.txt',
#    'Friends - 4x02 - The One With The Cat.ru.txt',
#    'Friends - 4x02 - The One With The Cat.Tv.ru.txt',
#    "Friends - 4x03 - The One With The 'Cuffs.ru.txt",
#    'Friends - 4x04 - The One With The Ballroom Dancing.ru.txt',
#    "Friends - 4x05 - The One With Joey's New Girlfriend.ru.txt",
#    'Friends - 4x06 - The One With The Dirty Girl.ru.txt',
#    'Friends - 4x07 - The One Where Chandler Crosses The Line.ru.txt',
#    'Friends - 4x08 - The One With Chandler In A Box.ru.txt',
#    "Friends - 4x09 - The One Where They're Going To Party!.ru.txt",
#    'Friends - 4x10 - The One With The Girl From Poughkeepsie.ru.txt',
#    "Friends - 4x11 - The One With Phoebe's Uterus.ru.txt",
#    'Friends - 4x12 - The One With The Embryos.ru.txt',
#    "Friends - 4x13 - The One With Rachel's Crush.ru.txt",
#    "Friends - 4x14 - The One With Joey's Dirty Day.ru.txt",
#    'Friends - 4x15 - The One With All The Rugby.ru.txt',
#    'Friends - 4x16 - The One With The Fake Party.ru.txt',
#    'Friends - 4x17 - The One With The Free Porn.ru.txt',
#    "Friends - 4x18 - The One With Rachel's New Dress.ru.txt",
#    'Friends - 4x19 - The One With All The Haste.ru.txt',
#    'Friends - 4x20 - The One With The Wedding Dresses.ru.txt',
#    'Friends - 4x21 - The One With The Invitations.ru.txt',
#    'Friends - 4x22 - The One With The Worst Best Man Ever.ru.txt',
#    "Friends - 4x23-24 - The One With Ross's Wedding (1).ru.txt",
#    "Friends - 4x24-25 - The One With Ross's Wedding (2).ru.txt"]),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 5',
#   [],
#   ['Friends - 5x01 - The One After Ross Says Rachel.ru.txt',
#    'Friends - 5x02 - The One With All The Kissing.ru.txt',
#    'Friends - 5x03 - The One Hundredth.ru.txt',
#    'Friends - 5x04 - The One Where Phoebe Hates PBS.ru.txt',
#    'Friends - 5x05 - The One With The Kips.ru.txt',
#    'Friends - 5x06 - The One With The Yeti.ru.txt',
#    'Friends - 5x07 - The One Where Ross Moves In.ru.txt',
#    'Friends - 5x08 - The One With The Thanksgiving Flashbacks.ru.txt',
#    "Friends - 5x09 - The One With Ross's Sandwich.ru.txt",
#    'Friends - 5x10 - The One With The Inappropriate Sister.ru.txt',
#    'Friends - 5x11 - The One With All The Resolutions.ru.txt',
#    "Friends - 5x12 - The One With Chandler's Work Laugh.ru.txt",
#    "Friends - 5x13 - The One With Joey's Bag.ru.txt",
#    'Friends - 5x14 - The One Where Everybody Finds Out.ru.txt',
#    'Friends - 5x15 - The One With The Girl Who Hits Joey.ru.txt',
#    'Friends - 5x16 - The One With The Cop.ru.txt',
#    "Friends - 5x17 - The One With Rachel's Inadvertent Kiss.ru.txt",
#    'Friends - 5x18 - The One Where Rachel Smokes.ru.txt',
#    "Friends - 5x19 - The One Where Ross Can't Flirt.ru.txt",
#    'Friends - 5x20 - The One With The Ride Along.ru.txt',
#    'Friends - 5x21 - The One With The Ball.ru.txt',
#    "Friends - 5x22 - The One With Joey's Big Break.ru.txt",
#    'Friends - 5x23-24 - The One In Vegas (1).ru.txt',
#    'Friends - 5x24-25 - The One In Vegas (2).ru.txt']),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 6',
#   [],
#   ['Friends - 6x01 - The One After Vegas.ru.txt',
#    'Friends - 6x02 - The One Where Ross Hugs Rachel.ru.txt',
#    "Friends - 6x03 - The One With Ross's Denial.ru.txt",
#    'Friends - 6x04 - The One Where Joey Loses His Insurance.ru.txt',
#    "Friends - 6x05 - The One With Joey's Porsche.ru.txt",
#    'Friends - 6x06 - The One On The Last Night.ru.txt',
#    'Friends - 6x07 - The One Where Phoebe Runs.ru.txt',
#    "Friends - 6x08 - The One With Ross's Teeth.ru.txt",
#    'Friends - 6x09 - The One Where Ross Got High.ru.txt',
#    'Friends - 6x10 - The One With The Routine.ru.txt',
#    'Friends - 6x11 - The One With The Apothecary Table.ru.txt',
#    'Friends - 6x12 - The One With The Joke.ru.txt',
#    "Friends - 6x13 - The One With Rachel's Sister (1).ru.txt",
#    "Friends - 6x14 - The One Where Chandler Can't Cry (2).ru.txt",
#    'Friends - 6x15 - The One That Could Have Been (1).ru.txt',
#    'Friends - 6x16-17 - The One That Could Have Been (2).ru.txt',
#    'Friends - 6x17 - The One With Unagi.ru.txt',
#    'Friends - 6x18 - The One Where Ross Dates A Student.ru.txt',
#    "Friends - 6x19 - The One With Joey's Fridge.ru.txt",
#    'Friends - 6x20 - The One With Mac And C.H.E.E.S.E..ru.txt',
#    "Friends - 6x21 - The One Where Ross Meets Elizabeth's Dad.ru.txt",
#    "Friends - 6x22 - The One Where Paul's The Man.ru.txt",
#    'Friends - 6x23 - The One With The Ring.ru.txt',
#    'Friends - 6x24 - The One With The Proposal (1).ru.txt',
#    'Friends - 6x25-26 - The One With The Proposal (2).ru.txt']),
#  ('C:\\Users\\Eduard\\Desktop\\Projects\\infosearch\\friends\\Friends - season 7',
#   [],
#   ["Friends - 7x01 - The One With Monica's Thunder.ru.txt",
#    "Friends - 7x02 - The One With Rachel's Book.ru.txt",
#    "Friends - 7x03 - The One With Phoebe's Cookies.ru.txt",
#    "Friends - 7x04 - The One With Rachel's Assistant.ru.txt",
#    'Friends - 7x05 - The One With The Engagement Picture.ru.txt',
#    'Friends - 7x06 - The One With The Nap Partners.ru.txt',
#    "Friends - 7x07 - The One With Ross's Library Book.ru.txt",
#    "Friends - 7x08 - The One Where Chandler Doesn't Like Dogs.ru.txt",
#    'Friends - 7x09 - The One With All The Candy.ru.txt',
#    'Friends - 7x10 - The One With The Holiday Armadillo.ru.txt',
#    'Friends - 7x11 - The One With All The Cheesecakes.ru.txt',
#    "Friends - 7x12 - The One Where They're Up All Night.ru.txt",
#    'Friends - 7x13 - The One Where Rosita Dies.ru.txt',
#    'Friends - 7x14 - The One Where They All Turn Thirty.ru.txt',
#    "Friends - 7x15 - The One With Joey's New Brain.ru.txt",
#    'Friends - 7x16 - The One With The Truth About London.ru.txt',
#    'Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt',
#    "Friends - 7x18 - The One With Joey's Award.ru.txt",
#    "Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt",
#    "Friends - 7x20 - The One With Rachel's Big Kiss.ru.txt",
#    'Friends - 7x21 - The One With The Vows.ru.txt',
#    "Friends - 7x22 - The One With Chandler's Dad.ru.txt",
#    "Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt",
#    "Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt"])]

# %% [markdown]
# ### чтение файла

# %%
fpath = 'test.txt'


# одним массивом
with open(fpath, 'r') as f:  
    text = f.read() 

    
#по строкам, в конце каждой строки \n  
with open(fpath, 'r') as f:   
    text = f.readlines() 

    
#по строкам, без \n   
with open(fpath, 'r') as f:   
    text = f.read().splitlines()

# %% [markdown]
# Напоминание про enumerate:
# > При итерации по списку вы можете помимо самого элемента получить его порядковый номер
# ``` for i, element in enumerate(your_list): ...  ```
# Иногда для получения элемента делают так -  ``` your_list[i] ```, не надо так

# %% [markdown]
# ##  Индекс
#
# Сам по себе индекс - это просто формат хранения данных, он не может осуществлять поиск. Для этого необходимо добавить к нему определенную метрику. Это может быть что-то простое типа булева поиска, а может быть что-то более специфическое или кастомное под задачу.
#
# Давайте посмотрим, что полезного можно вытащить из самого индекса.
# По сути, индекс - это информация о частоте встречаемости слова в каждом документе.
# Из этого можно понять, например:
# 1. какое слово является самым часто употребимым / редким
# 2. какие слова встречаются всегда вместе - так можно парсить твиттер, fb, форумы и отлавливать новые устойчивые выражения в речи
# 3. как эти документы кластеризуются по N тематикам согласно словам, которые в них упоминаются

# %% [markdown]
# ## __Задача__:
#
# **Data:** Коллекция субтитров сезонов Друзьей. Одна серия - один документ.
#
# **To do:** Постройте небольшой модуль поискового движка, который сможет осуществлять поиск по коллекции документов.
# На входе запрос и проиндексированная коллекция (в том виде, как посчитаете нужным), на выходе отсортированный по релевантности с запросом список документов коллекции.
#
# Релизуйте:
#     - функцию препроцессинга данных
#     - функцию индексирования данных
#     - функцию метрики релевантности
#     - собственно, функцию поиска
#
# [download_friends_corpus](https://yadi.sk/d/yVO1QV98CDibpw)

# %% [markdown]
# Напоминание про defaultdict:
# > В качестве multiple values словаря рекомендую использовать ``` collections.defaultdict ```
# > Так можно избежать конструкции ``` dict.setdefault(key, default=None) ```

# %%
### _check : в коллекции должно быть около 165 файлов

# %%
# import libraries
import os
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from string import punctuation
punctuation += '…—'
# !pip install pymorphy2[fast]
from pymorphy2 import MorphAnalyzer
from collections import Counter, defaultdict
import math
import json
import numpy as np
import pandas as pd
from scipy import spatial
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Eduard\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Eduard\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: pymorphy2[fast] in c:\users\eduard\anaconda3\lib\site-packages (0.8)
# Requirement already satisfied: dawg-python>=0.7 in c:\users\eduard\anaconda3\lib\site-packages (from pymorphy2[fast]) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in c:\users\eduard\anaconda3\lib\site-packages (from pymorphy2[fast]) (2.4.393442.3710985)
# Requirement already satisfied: docopt>=0.6 in c:\users\eduard\anaconda3\lib\site-packages (from pymorphy2[fast]) (0.6.2)
# Requirement already satisfied: DAWG>=0.7.3; extra == "fast" in c:\users\eduard\anaconda3\lib\site-packages (from pymorphy2[fast]) (0.7.8)

# %%
# ~ global variables
pymorphy2_analyzer = MorphAnalyzer()
rus_stopwords = stopwords.words('russian')

# %%
# функция препроцессинга данных
def preprocess_text(text, save_stopwords=True):
    lowered_tokens = [word.strip(punctuation) for word in word_tokenize(text.lower()) if word.strip(punctuation)]
    if save_stopwords:
        return [pymorphy2_analyzer.normal_forms(token)[0] for token in lowered_tokens]
    return [pymorphy2_analyzer.normal_forms(token)[0] for token in lowered_tokens if pymorphy2_analyzer.normal_forms(token)[0] not in rus_stopwords]

# %%
# функция индексирования данных
def inverted_index(text, text_id):
    text_length = len(text)
    return {key: (text_id, value, text_length) for key, value in Counter(text).items()}

# %%
# функция метрики релевантности
def average_precision_at_k(predicted_answers, true_answers, k=3):
    sum = 0
    count = 0
    for index, predicted_answer in enumerate(predicted_answers[:k]):
        if predicted_answer in true_answers[:k]:
            count += 1
            sum += count / (index + 1)
    return sum / k

# %%
# get inverted_collection
def get_inverted_collection(curr_dir, save_stopwords=True):
    inverted_collection = defaultdict(list)
    for root, dirs, files in os.walk(curr_dir):
        for file in files:
            with open(os.path.join(root, file), 'r', encoding='utf-8-sig') as f:
                for token, value in inverted_index(preprocess_text(f.read(), save_stopwords=save_stopwords), file).items():
                    inverted_collection[token].append(value)
    return inverted_collection

# %%
curr_dir = os.path.abspath('friends')

# %%
with open('inverted_collection_with_stopwords.json', 'w', encoding='utf-8') as f:
    json.dump(get_inverted_collection(curr_dir, save_stopwords=True), f)
with open('inverted_collection_without_stopwords.json', 'w', encoding='utf-8') as f:
    json.dump(get_inverted_collection(curr_dir, save_stopwords=False), f)

# %%
# функция поиска
def search(request, inverted_collection, save_stopwords=True):
    vec_size = len(inverted_collection)
    print(vec_size, 'words')
    unique_docs = {triple[0] for triples in inverted_collection.values() for triple in triples}
    num_of_docs = len(unique_docs)
    print(num_of_docs, 'docs')

    index = pd.Index(unique_docs, name='docs')
    columns = pd.Index(inverted_collection.keys(), name='words')
    df = pd.DataFrame(0., index=index, columns=columns)
    for word, triples in inverted_collection.items():
        idf = math.log10(num_of_docs / len(triples))  # I didn't add 1 to the denominator as pairs is definitely not an empty array
        for triple in triples:
            tf = triple[1] / triple[2]
            df.at[triple[0], word] = tf * idf

    request_dct = inverted_index(preprocess_text(request, save_stopwords=save_stopwords), 'request')
    removed_keys = set(request_dct.keys()) - set(inverted_collection.keys())
    for removed_key in removed_keys:
        del request_dct[removed_key]

    request_vec = np.zeros((1, vec_size))
    columns_list = columns.values.tolist()
    for word, triple in request_dct.items():
        tf = triple[1] / triple[2]
        idf = math.log10(num_of_docs / len(inverted_collection[word]))
        request_vec[0][columns_list.index(word)] = tf * idf

    rows_list = index.values.tolist()
    doc_to_cosine = {}
    for row in rows_list:
        doc_to_cosine[row] = 1 - spatial.distance.cosine(df.loc[row], request_vec)

    return [pair[0] for pair in sorted(doc_to_cosine.items(), key=lambda elem: -elem[1])]

# %%
with open('inverted_collection_with_stopwords.json', 'r', encoding='utf-8') as f:
    inverted_collection_with_stopwords = json.load(f)

with open('inverted_collection_without_stopwords.json', 'r', encoding='utf-8') as f:
    inverted_collection_without_stopwords = json.load(f)

# %%
our_order = search('Разве это не чудесно?', inverted_collection_with_stopwords, save_stopwords=True)
# Out:
# 15748 words
# 165 docs

# %%
our_order
# Out:
# ["Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt",
#  "Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt",
#  'Friends - 6x25-26 - The One With The Proposal (2).ru.txt',
#  'Friends - 3x18 - The One With The Hypnosis Tape.ru.txt',
#  'Friends - 2x16 - The One Where Joey Moves Out.ru.txt',
#  'Friends - 3x13 - The One Where Monica And Richard Are Just Friends.ru.txt',
#  'Friends - 1x08 - The One Where Nana Dies Twice.ru.txt',
#  'Friends - 2x20 - The One Where Old Yeller Dies.NurlanB.ru.txt',
#  'Friends - 6x04 - The One Where Joey Loses His Insurance.ru.txt',
#  'Friends - 5x23-24 - The One In Vegas (1).ru.txt',
#  "Friends - 6x13 - The One With Rachel's Sister (1).ru.txt",
#  'Friends - 2x05 - The One With Five Steaks And An Eggplant.ru.txt',
#  'Friends - 2x18 - The One Where Dr. Ramoray Dies.ru.txt',
#  'Friends - 2x23 - The One With The Chicken Pox.ru.txt',
#  "Friends - 3x11 - The One Where Chandler Can't Remember Which Sister.ru.txt",
#  'Friends - 4x21 - The One With The Invitations.ru.txt',
#  'Friends - 2x14 - The One With The Prom Video.ru.txt',
#  'Friends - 6x02 - The One Where Ross Hugs Rachel.ru.txt',
#  'Friends - 3x20 - The One With The Dollhouse.ru.txt',
#  "Friends - 7x03 - The One With Phoebe's Cookies.ru.txt",
#  'Friends - 5x14 - The One Where Everybody Finds Out.ru.txt',
#  'Friends - 4x20 - The One With The Wedding Dresses.ru.txt',
#  "Friends - 5x12 - The One With Chandler's Work Laugh.ru.txt",
#  'Friends - 6x07 - The One Where Phoebe Runs.ru.txt',
#  'Friends - 3x19 - The One With The Tiny T-Shirt.ru.txt',
#  'Friends - 4x08 - The One With Chandler In A Box.ru.txt',
#  "Friends - 6x21 - The One Where Ross Meets Elizabeth's Dad.ru.txt",
#  "Friends - 4x09 - The One Where They're Going To Party!.ru.txt",
#  "Friends - 4x05 - The One With Joey's New Girlfriend.ru.txt",
#  'Friends - 3x15 - The One Where Ross And Rachel Take A Break (1).ru.txt',
#  'Friends - 7x16 - The One With The Truth About London.ru.txt',
#  'Friends - 3x07 - The One With The Race Car Bed.ru.txt',
#  'Friends - 6x17 - The One With Unagi.ru.txt',
#  'Friends - 5x07 - The One Where Ross Moves In.ru.txt',
#  'Friends - 1x01 - The One Where Monica Gets A Roommate.ru.txt',
#  'Friends - 3x10 - The One Where Rachel Quits.ru.txt',
#  'Friends - 5x01 - The One After Ross Says Rachel.ru.txt',
#  'Friends - 3x16 - The One With The Morning After (2).ru.txt',
#  'Friends - 6x11 - The One With The Apothecary Table.ru.txt',
#  'Friends - 2x11 - The One With The Lesbian Wedding.ru.txt',
#  "Friends - 7x07 - The One With Ross's Library Book.ru.txt",
#  "Friends - 4x23-24 - The One With Ross's Wedding (1).ru.txt",
#  'Friends - 1x17 - The One With Two Parts (2).ru.txt',
#  'Friends - 4x06 - The One With The Dirty Girl.ru.txt',
#  "Friends - 7x20 - The One With Rachel's Big Kiss.ru.txt",
#  'Friends - 1x02 - The One With The Sonogram At The End.ru.txt',
#  'Friends - 5x15 - The One With The Girl Who Hits Joey.ru.txt',
#  "Friends - 4x03 - The One With The 'Cuffs.ru.txt",
#  "Friends - 5x17 - The One With Rachel's Inadvertent Kiss.ru.txt",
#  'Friends - 2x12 - The One After The Super Bowl (1).ru.txt',
#  'Friends - 6x15 - The One That Could Have Been (1).ru.txt',
#  'Friends - 5x10 - The One With The Inappropriate Sister.ru.txt',
#  "Friends - 2x09 - The One With Phoebe's Dad.ru.txt",
#  'Friends - 5x06 - The One With The Yeti.ru.txt',
#  'Friends - 1x20 - The One With The Evil Orthodontist.ru.txt',
#  "Friends - 3x02 - The One Where No One's Ready.ru.txt",
#  'Friends - 1x05 - The One With The East German Laundry Detergent.ru.txt',
#  "Friends - 5x13 - The One With Joey's Bag.ru.txt",
#  'Friends - 2x10 - The One With Russ.ru.txt',
#  'Friends - 7x11 - The One With All The Cheesecakes.ru.txt',
#  'Friends - 4x22 - The One With The Worst Best Man Ever.ru.txt',
#  'Friends - 1x10 - The One With The Monkey.ru.txt',
#  "Friends - 6x08 - The One With Ross's Teeth.ru.txt",
#  "Friends - 5x19 - The One Where Ross Can't Flirt.ru.txt",
#  'Friends - 7x13 - The One Where Rosita Dies.ru.txt',
#  'Friends - 5x18 - The One Where Rachel Smokes.ru.txt',
#  'Friends - 7x10 - The One With The Holiday Armadillo.ru.txt',
#  'Friends - 2x07 - The One Where Ross Finds Out.ru.txt',
#  'Friends - 6x16-17 - The One That Could Have Been (2).ru.txt',
#  "Friends - 2x04 - The One With Phoebe's Husband.ru.txt",
#  'Friends - 6x01 - The One After Vegas.ru.txt',
#  "Friends - 2x24 - The One With Barry And Mindy's Wedding.ru.txt",
#  'Friends - 7x14 - The One Where They All Turn Thirty.ru.txt',
#  'Friends - 5x05 - The One With The Kips.ru.txt',
#  'Friends - 6x20 - The One With Mac And C.H.E.E.S.E..ru.txt',
#  "Friends - 4x11 - The One With Phoebe's Uterus.ru.txt",
#  'Friends - 3x01 - The One With The Princess Leia Fantasy.ru.txt',
#  'Friends - 7x05 - The One With The Engagement Picture.ru.txt',
#  'Friends - 4x04 - The One With The Ballroom Dancing.ru.txt',
#  'Friends - 3x21 - The One With A Chick And A Duck.ru.txt',
#  'Friends - 1x12 - The One With The Dozen Lasagnas.ru.txt',
#  'Friends - 6x24 - The One With The Proposal (1).ru.txt',
#  'Friends - 6x06 - The One On The Last Night.ru.txt',
#  'Friends - 1x14 - The One With The Candy Hearts.ru.txt',
#  "Friends - 4x13 - The One With Rachel's Crush.ru.txt",
#  'Friends - 5x20 - The One With The Ride Along.ru.txt',
#  'Friends - 2x13 - The One After The Super Bowl (2).ru.txt',
#  "Friends - 2x01 - The One With Ross's New Girlfriend.ru.txt",
#  'Friends - 5x04 - The One Where Phoebe Hates PBS.ru.txt',
#  'Friends - 5x02 - The One With All The Kissing.ru.txt',
#  'Friends - 6x18 - The One Where Ross Dates A Student.ru.txt',
#  'Friends - 3x17 - The One Without The Ski Trip.ru.txt',
#  "Friends - 2x01 - The One With Ross's New Girlfriend.DVDRip.ru.txt",
#  "Friends - 4x18 - The One With Rachel's New Dress.ru.txt",
#  'Friends - 1x16 - The One With Two Parts (1).ru.txt',
#  'Friends - 5x16 - The One With The Cop.ru.txt',
#  'Friends - 1x04 - The One With George Stephanopoulos.ru.txt',
#  "Friends - 7x15 - The One With Joey's New Brain.ru.txt",
#  "Friends - 6x14 - The One Where Chandler Can't Cry (2).ru.txt",
#  'Friends - 3x12 - The One With All The Jealousy.ru.txt',
#  'Friends - 2x21 - The One With The Bullies.ru.txt',
#  'Friends - 2x22 - The One With The Two Parties.ru.txt',
#  'Friends - 4x15 - The One With All The Rugby.ru.txt',
#  "Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt",
#  'Friends - 3x08 - The One With The Giant Poking Device.ru.txt',
#  'Friends - 2x08 - The One With The List.ru.txt',
#  "Friends - 6x19 - The One With Joey's Fridge.ru.txt",
#  "Friends - 7x12 - The One Where They're Up All Night.ru.txt",
#  'Friends - 6x09 - The One Where Ross Got High.ru.txt',
#  "Friends - 4x14 - The One With Joey's Dirty Day.ru.txt",
#  'Friends - 1x18 - The One With All The Poker.ru.txt',
#  'Friends - 4x02 - The One With The Cat.Tv.ru.txt',
#  'Friends - 5x21 - The One With The Ball.ru.txt',
#  'Friends - 3x09 - The One With The Football.ru.txt',
#  'Friends - 2x17 - The One Where Eddie Moves In.ru.txt',
#  'Friends - 4x10 - The One With The Girl From Poughkeepsie.ru.txt',
#  'Friends - 1x07 - The One With The Blackout.ru.txt',
#  'Friends - 4x19 - The One With All The Haste.ru.txt',
#  'Friends - 4x01 - The One With The Jellyfish.ru.txt',
#  'Friends - 3x03 - The One With The Jam.ru.txt',
#  "Friends - 7x08 - The One Where Chandler Doesn't Like Dogs.ru.txt",
#  "Friends - 5x22 - The One With Joey's Big Break.ru.txt",
#  'Friends - 4x02 - The One With The Cat.ru.txt',
#  'Friends - 4x01 - The One With The Jellyfish.Tv.ru.txt',
#  'Friends - 4x12 - The One With The Embryos.ru.txt',
#  'Friends - 1x13 - The One With The Boobies.ru.txt',
#  'Friends - 3x06 - The One With The Flashback.ru.txt',
#  'Friends - 1x03 - The One With The Thumb.ru.txt',
#  "Friends - 7x02 - The One With Rachel's Book.ru.txt",
#  'Friends - 2x02 - The One With The Breast Milk.ru.txt',
#  "Friends - 6x05 - The One With Joey's Porsche.ru.txt",
#  "Friends - 3x14 - The One With Phoebe's Ex-Partner.ru.txt",
#  "Friends - 7x18 - The One With Joey's Award.ru.txt",
#  'Friends - 6x12 - The One With The Joke.ru.txt',
#  'Friends - 5x24-25 - The One In Vegas (2).ru.txt',
#  "Friends - 6x03 - The One With Ross's Denial.ru.txt",
#  'Friends - 4x16 - The One With The Fake Party.ru.txt',
#  "Friends - 7x22 - The One With Chandler's Dad.ru.txt",
#  'Friends - 7x06 - The One With The Nap Partners.ru.txt',
#  'Friends - 5x03 - The One Hundredth.ru.txt',
#  'Friends - 4x07 - The One Where Chandler Crosses The Line.ru.txt',
#  'Friends - 5x08 - The One With The Thanksgiving Flashbacks.ru.txt',
#  'Friends - 3x04 - The One With The Metaphorical Tunnel.ru.txt',
#  'Friends - 5x11 - The One With All The Resolutions.ru.txt',
#  "Friends - 7x01 - The One With Monica's Thunder.ru.txt",
#  'Friends - 1x15 - The One With The Stoned Guy.ru.txt',
#  'Friends - 6x10 - The One With The Routine.ru.txt',
#  'Friends - 4x17 - The One With The Free Porn.ru.txt',
#  'Friends - 7x09 - The One With All The Candy.ru.txt',
#  "Friends - 5x09 - The One With Ross's Sandwich.ru.txt",
#  "Friends - 6x22 - The One Where Paul's The Man.ru.txt",
#  'Friends - 6x23 - The One With The Ring.ru.txt',
#  'Friends - 1x11 - The One With Mrs. Bing.ru.txt',
#  'Friends - 1x19 - The One Where The Monkey Gets Away.ru.txt',
#  'Friends - 1x06 - The One With The Butt.ru.txt',
#  'Friends - 2x15 - The One Where Ross And Rachel...You Know.ru.txt',
#  'Friends - 2x06 - The One With The Baby On The Bus.ru.txt',
#  'Friends - 1x09 - The One Where Underdog Gets Away.ru.txt',
#  'Friends - 2x03 - The One Where Heckles Dies.ru.txt',
#  'Friends - 3x05 - The One With Frank Jr..ru.txt',
#  'Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt',
#  'Friends - 7x21 - The One With The Vows.ru.txt',
#  "Friends - 2x19 - The One Where Eddie Won't Go.ru.txt",
#  "Friends - 7x04 - The One With Rachel's Assistant.ru.txt",
#  "Friends - 4x24-25 - The One With Ross's Wedding (2).ru.txt"]

# %% [markdown]
# Предположим, что следующий порядок является правильным (`топ-10`) для запроса 'Разве это не чудесно?':

# %%
correct_order = [
    'Friends - 6x25-26 - The One With The Proposal (2).ru.txt',
    'Friends - 1x08 - The One Where Nana Dies Twice.ru.txt',
    "Friends - 3x11 - The One Where Chandler Can't Remember Which Sister.ru.txt",
    "Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt",
    'Friends - 2x18 - The One Where Dr. Ramoray Dies.ru.txt',
    "Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt",
    'Friends - 2x16 - The One Where Joey Moves Out.ru.txt',
    'Friends - 2x05 - The One With Five Steaks And An Eggplant.ru.txt',
    "Friends - 6x13 - The One With Rachel's Sister (1).ru.txt",
    'Friends - 3x18 - The One With The Hypnosis Tape.ru.txt'
]

# %% [markdown]
# Тогда можно посчитать метрику релевантности нашего алгоритма `average_precision_at_k`:

# %%
precision = []
for k in range(1, 11):
    precision.append(average_precision_at_k(our_order, correct_order, k=k))
plt.plot(range(1, 11), precision)

# %%
search('Тебе плевать на неприкосновенность моего жилища?', inverted_collection_without_stopwords, save_stopwords=False)
# Out:
# 15642 words
# 165 docs
# ['Friends - 1x13 - The One With The Boobies.ru.txt',
#  "Friends - 7x23 - The One With Chandler And Monica's Wedding (1).ru.txt",
#  "Friends - 4x13 - The One With Rachel's Crush.ru.txt",
#  'Friends - 3x08 - The One With The Giant Poking Device.ru.txt',
#  'Friends - 5x01 - The One After Ross Says Rachel.ru.txt',
#  "Friends - 7x01 - The One With Monica's Thunder.ru.txt",
#  "Friends - 7x22 - The One With Chandler's Dad.ru.txt",
#  'Friends - 1x16 - The One With Two Parts (1).ru.txt',
#  'Friends - 5x11 - The One With All The Resolutions.ru.txt',
#  'Friends - 4x12 - The One With The Embryos.ru.txt',
#  "Friends - 3x14 - The One With Phoebe's Ex-Partner.ru.txt",
#  'Friends - 2x23 - The One With The Chicken Pox.ru.txt',
#  'Friends - 1x07 - The One With The Blackout.ru.txt',
#  'Friends - 3x10 - The One Where Rachel Quits.ru.txt',
#  'Friends - 6x23 - The One With The Ring.ru.txt',
#  "Friends - 3x11 - The One Where Chandler Can't Remember Which Sister.ru.txt",
#  'Friends - 7x13 - The One Where Rosita Dies.ru.txt',
#  'Friends - 1x19 - The One Where The Monkey Gets Away.ru.txt',
#  'Friends - 2x12 - The One After The Super Bowl (1).ru.txt',
#  'Friends - 6x01 - The One After Vegas.ru.txt',
#  "Friends - 4x03 - The One With The 'Cuffs.ru.txt",
#  'Friends - 2x05 - The One With Five Steaks And An Eggplant.ru.txt',
#  "Friends - 2x04 - The One With Phoebe's Husband.ru.txt",
#  "Friends - 7x20 - The One With Rachel's Big Kiss.ru.txt",
#  'Friends - 2x13 - The One After The Super Bowl (2).ru.txt',
#  'Friends - 3x18 - The One With The Hypnosis Tape.ru.txt',
#  'Friends - 7x11 - The One With All The Cheesecakes.ru.txt',
#  'Friends - 3x15 - The One Where Ross And Rachel Take A Break (1).ru.txt',
#  'Friends - 6x02 - The One Where Ross Hugs Rachel.ru.txt',
#  'Friends - 7x05 - The One With The Engagement Picture.ru.txt',
#  'Friends - 4x10 - The One With The Girl From Poughkeepsie.ru.txt',
#  'Friends - 5x18 - The One Where Rachel Smokes.ru.txt',
#  'Friends - 3x09 - The One With The Football.ru.txt',
#  'Friends - 6x06 - The One On The Last Night.ru.txt',
#  'Friends - 6x18 - The One Where Ross Dates A Student.ru.txt',
#  'Friends - 4x22 - The One With The Worst Best Man Ever.ru.txt',
#  'Friends - 2x17 - The One Where Eddie Moves In.ru.txt',
#  'Friends - 2x08 - The One With The List.ru.txt',
#  "Friends - 5x12 - The One With Chandler's Work Laugh.ru.txt",
#  'Friends - 2x18 - The One Where Dr. Ramoray Dies.ru.txt',
#  'Friends - 5x04 - The One Where Phoebe Hates PBS.ru.txt',
#  'Friends - 4x19 - The One With All The Haste.ru.txt',
#  "Friends - 2x01 - The One With Ross's New Girlfriend.DVDRip.ru.txt",
#  'Friends - 5x15 - The One With The Girl Who Hits Joey.ru.txt',
#  'Friends - 4x20 - The One With The Wedding Dresses.ru.txt',
#  'Friends - 1x17 - The One With Two Parts (2).ru.txt',
#  'Friends - 3x17 - The One Without The Ski Trip.ru.txt',
#  "Friends - 7x12 - The One Where They're Up All Night.ru.txt",
#  'Friends - 4x01 - The One With The Jellyfish.ru.txt',
#  'Friends - 3x03 - The One With The Jam.ru.txt',
#  'Friends - 5x02 - The One With All The Kissing.ru.txt',
#  "Friends - 7x08 - The One Where Chandler Doesn't Like Dogs.ru.txt",
#  "Friends - 5x22 - The One With Joey's Big Break.ru.txt",
#  'Friends - 6x20 - The One With Mac And C.H.E.E.S.E..ru.txt',
#  'Friends - 3x07 - The One With The Race Car Bed.ru.txt',
#  'Friends - 4x02 - The One With The Cat.ru.txt',
#  'Friends - 4x04 - The One With The Ballroom Dancing.ru.txt',
#  'Friends - 6x25-26 - The One With The Proposal (2).ru.txt',
#  'Friends - 3x01 - The One With The Princess Leia Fantasy.ru.txt',
#  'Friends - 5x07 - The One Where Ross Moves In.ru.txt',
#  'Friends - 4x01 - The One With The Jellyfish.Tv.ru.txt',
#  'Friends - 5x23-24 - The One In Vegas (1).ru.txt',
#  "Friends - 7x24-25 - The One With Chandler And Monica's Wedding (2).ru.txt",
#  'Friends - 3x06 - The One With The Flashback.ru.txt',
#  "Friends - 2x09 - The One With Phoebe's Dad.ru.txt",
#  'Friends - 5x10 - The One With The Inappropriate Sister.ru.txt',
#  'Friends - 6x11 - The One With The Apothecary Table.ru.txt',
#  'Friends - 5x21 - The One With The Ball.ru.txt',
#  'Friends - 1x03 - The One With The Thumb.ru.txt',
#  "Friends - 5x19 - The One Where Ross Can't Flirt.ru.txt",
#  "Friends - 7x02 - The One With Rachel's Book.ru.txt",
#  'Friends - 2x10 - The One With Russ.ru.txt',
#  "Friends - 6x21 - The One Where Ross Meets Elizabeth's Dad.ru.txt",
#  'Friends - 2x02 - The One With The Breast Milk.ru.txt',
#  'Friends - 2x21 - The One With The Bullies.ru.txt',
#  'Friends - 1x08 - The One Where Nana Dies Twice.ru.txt',
#  "Friends - 4x05 - The One With Joey's New Girlfriend.ru.txt",
#  "Friends - 6x05 - The One With Joey's Porsche.ru.txt",
#  "Friends - 5x13 - The One With Joey's Bag.ru.txt",
#  "Friends - 3x02 - The One Where No One's Ready.ru.txt",
#  'Friends - 6x17 - The One With Unagi.ru.txt',
#  'Friends - 1x14 - The One With The Candy Hearts.ru.txt',
#  'Friends - 6x07 - The One Where Phoebe Runs.ru.txt',
#  "Friends - 7x18 - The One With Joey's Award.ru.txt",
#  'Friends - 5x16 - The One With The Cop.ru.txt',
#  'Friends - 3x13 - The One Where Monica And Richard Are Just Friends.ru.txt',
#  'Friends - 7x10 - The One With The Holiday Armadillo.ru.txt',
#  'Friends - 6x12 - The One With The Joke.ru.txt',
#  "Friends - 4x11 - The One With Phoebe's Uterus.ru.txt",
#  'Friends - 5x24-25 - The One In Vegas (2).ru.txt',
#  "Friends - 6x19 - The One With Joey's Fridge.ru.txt",
#  "Friends - 6x03 - The One With Ross's Denial.ru.txt",
#  'Friends - 3x20 - The One With The Dollhouse.ru.txt',
#  'Friends - 6x09 - The One Where Ross Got High.ru.txt',
#  'Friends - 4x16 - The One With The Fake Party.ru.txt',
#  "Friends - 7x15 - The One With Joey's New Brain.ru.txt",
#  'Friends - 4x08 - The One With Chandler In A Box.ru.txt',
#  'Friends - 7x06 - The One With The Nap Partners.ru.txt',
#  'Friends - 6x16-17 - The One That Could Have Been (2).ru.txt',
#  'Friends - 5x03 - The One Hundredth.ru.txt',
#  'Friends - 2x20 - The One Where Old Yeller Dies.NurlanB.ru.txt',
#  'Friends - 3x19 - The One With The Tiny T-Shirt.ru.txt',
#  "Friends - 2x01 - The One With Ross's New Girlfriend.ru.txt",
#  'Friends - 5x20 - The One With The Ride Along.ru.txt',
#  'Friends - 4x06 - The One With The Dirty Girl.ru.txt',
#  'Friends - 1x04 - The One With George Stephanopoulos.ru.txt',
#  'Friends - 4x07 - The One Where Chandler Crosses The Line.ru.txt',
#  'Friends - 5x08 - The One With The Thanksgiving Flashbacks.ru.txt',
#  "Friends - 7x03 - The One With Phoebe's Cookies.ru.txt",
#  'Friends - 3x04 - The One With The Metaphorical Tunnel.ru.txt',
#  'Friends - 1x18 - The One With All The Poker.ru.txt',
#  "Friends - 7x19 - The One With Ross And Monica's Cousin.ru.txt",
#  'Friends - 6x15 - The One That Could Have Been (1).ru.txt',
#  'Friends - 1x15 - The One With The Stoned Guy.ru.txt',
#  'Friends - 6x10 - The One With The Routine.ru.txt',
#  "Friends - 4x09 - The One Where They're Going To Party!.ru.txt",
#  'Friends - 4x17 - The One With The Free Porn.ru.txt',
#  'Friends - 7x09 - The One With All The Candy.ru.txt',
#  'Friends - 2x07 - The One Where Ross Finds Out.ru.txt',
#  'Friends - 1x01 - The One Where Monica Gets A Roommate.ru.txt',
#  "Friends - 5x09 - The One With Ross's Sandwich.ru.txt",
#  'Friends - 6x04 - The One Where Joey Loses His Insurance.ru.txt',
#  "Friends - 6x22 - The One Where Paul's The Man.ru.txt",
#  'Friends - 1x02 - The One With The Sonogram At The End.ru.txt',
#  'Friends - 5x06 - The One With The Yeti.ru.txt',
#  "Friends - 4x18 - The One With Rachel's New Dress.ru.txt",
#  'Friends - 1x20 - The One With The Evil Orthodontist.ru.txt',
#  'Friends - 4x02 - The One With The Cat.Tv.ru.txt',
#  "Friends - 4x23-24 - The One With Ross's Wedding (1).ru.txt",
#  'Friends - 1x11 - The One With Mrs. Bing.ru.txt',
#  "Friends - 6x14 - The One Where Chandler Can't Cry (2).ru.txt",
#  'Friends - 2x16 - The One Where Joey Moves Out.ru.txt',
#  'Friends - 1x06 - The One With The Butt.ru.txt',
#  'Friends - 5x05 - The One With The Kips.ru.txt',
#  'Friends - 3x12 - The One With All The Jealousy.ru.txt',
#  "Friends - 6x08 - The One With Ross's Teeth.ru.txt",
#  'Friends - 2x15 - The One Where Ross And Rachel...You Know.ru.txt',
#  'Friends - 2x06 - The One With The Baby On The Bus.ru.txt',
#  "Friends - 7x07 - The One With Ross's Library Book.ru.txt",
#  'Friends - 2x11 - The One With The Lesbian Wedding.ru.txt',
#  'Friends - 7x14 - The One Where They All Turn Thirty.ru.txt',
#  'Friends - 1x09 - The One Where Underdog Gets Away.ru.txt',
#  'Friends - 2x03 - The One Where Heckles Dies.ru.txt',
#  "Friends - 4x14 - The One With Joey's Dirty Day.ru.txt",
#  'Friends - 4x21 - The One With The Invitations.ru.txt',
#  'Friends - 3x21 - The One With A Chick And A Duck.ru.txt',
#  'Friends - 2x14 - The One With The Prom Video.ru.txt',
#  'Friends - 2x22 - The One With The Two Parties.ru.txt',
#  'Friends - 3x05 - The One With Frank Jr..ru.txt',
#  'Friends - 7x17 - The One With The Cheap Wedding Dress.ru.txt',
#  'Friends - 5x14 - The One Where Everybody Finds Out.ru.txt',
#  'Friends - 4x15 - The One With All The Rugby.ru.txt',
#  "Friends - 5x17 - The One With Rachel's Inadvertent Kiss.ru.txt",
#  'Friends - 1x12 - The One With The Dozen Lasagnas.ru.txt',
#  'Friends - 7x21 - The One With The Vows.ru.txt',
#  "Friends - 2x24 - The One With Barry And Mindy's Wedding.ru.txt",
#  "Friends - 2x19 - The One Where Eddie Won't Go.ru.txt",
#  "Friends - 7x04 - The One With Rachel's Assistant.ru.txt",
#  'Friends - 3x16 - The One With The Morning After (2).ru.txt',
#  'Friends - 1x05 - The One With The East German Laundry Detergent.ru.txt',
#  'Friends - 6x24 - The One With The Proposal (1).ru.txt',
#  'Friends - 7x16 - The One With The Truth About London.ru.txt',
#  "Friends - 6x13 - The One With Rachel's Sister (1).ru.txt",
#  "Friends - 4x24-25 - The One With Ross's Wedding (2).ru.txt",
#  'Friends - 1x10 - The One With The Monkey.ru.txt']

# %% [markdown]
# С помощью обратного индекса посчитайте:
#
#
# a) какое слово является самым частотным
#
# b) какое самым редким
#
# c) какой набор слов есть во всех документах коллекции
#
# d) какой сезон был самым популярным у Чендлера? у Моники?
#
# e) кто из главных героев статистически самый популярный?

# %%
def count_frequency(absolute=False, stopwords=True, minus=True):
    word_to_count = {}
    if stopwords:
        inverted_collection = inverted_collection_with_stopwords
    else:
        inverted_collection = inverted_collection_without_stopwords
    for word, triples in inverted_collection.items():
        if absolute:
            word_to_count[word] = sum([triple[1] for triple in triples])
        else:
            word_to_count[word] = len(triples)
    if minus:
        lst = sorted(word_to_count.items(), key=lambda kv: -kv[1])
    else:
        lst = sorted(word_to_count.items(), key=lambda kv: kv[1])
    results = []
    for pair in lst:
        if pair[1] != lst[0][1]:
            break
        results.append(pair[0])
    return lst[0][1], results

# %%
# a (подразумеваю леммы)

print('Со стопсловами:')

# 1)
value, results = count_frequency()
print(f'Самые частотные по встречаемости в документах ({value}):', ', '.join(results))

# 2)
value, results = count_frequency(absolute=True)
print(f'Самые частотные по абсолютной встречаемости ({value}):', ', '.join(results))

print()

print('Без стопслов:')

# 1) 
value, results = count_frequency(stopwords=False)
print(f'Самые частотные по встречаемости в документах ({value}):', ', '.join(results))

# 2)
value, results = count_frequency(absolute=True, stopwords=False)
print(f'Самые частотные по абсолютной встречаемости ({value}):', ', '.join(results))
# Out:
# Со стопсловами:
# Самые частотные по встречаемости в документах (165): как, весь, да, он, просто, ты, на, с, не, мочь, быть, так, у, и, в, я, знать, ну, хотеть, она, что, это, такой, мы, а, тот, мой, нет, если, сказать, этот, о, ещё, но, думать
# Самые частотные по абсолютной встречаемости (18475): я
#
# Без стопслов:
# Самые частотные по встречаемости в документах (165): весь, просто, мочь, знать, хотеть, это, сказать, ещё, думать
# Самые частотные по абсолютной встречаемости (7506): это

# %%
# б (подразумеваю леммы)

print('Со стопсловами:')

# 1)
value, results = count_frequency(minus=False)
print(f'Самые редкие по встречаемости в документах ({value}):', ', '.join(results))

print()

# 2)
value, results = count_frequency(absolute=True, minus=False)
print(f'Самые редкие по абсолютной встречаемости ({value}):', ', '.join(results))

print()

print('Без стопслов:')

# 1) 
value, results = count_frequency(stopwords=False, minus=False)
print(f'Самые редкие по встречаемости в документах ({value}):', ', '.join(results))

print()

# 2)
value, results = count_frequency(absolute=True, stopwords=False, minus=False)
print(f'Самые редкие по абсолютной встречаемости ({value}):', ', '.join(results))
# Out:
# Со стопсловами:
# Самые редкие по встречаемости в документах (1): придурь, горб, придача, старшеклассник, обмотать, чмо, зацикливаться, истерический, всхлип, лимож, сахарок, тут-то, человек-картошка, трубчатый, орган, столкнуть, запутаться, росинка, тычинка, пестик, рваный, гм, полседьмого, вбузздить, вино-половина, вино-полом, у-уй, уписаться, кипяток, ящерица, кишкоизвержение, присобачить, скоба, боковина, гэ, прикрепляться, пила, сваливать, отбеливать, банный, скотина, отрубиться, финклый, 26, даваться, полным-полно, вишнево-ванильный, посыпка, откровение, джоани, каннингем, чача, суперпремьера, бриолин, анжел, приглашать-то, вторгнуться, польша, по-ковбойски, бивис, батхед, сеновал, театрик, возмутить, попугаячий, вино-пола, наукообразный, отравлять, распространять, сапог, энд, полцена, потому-то, портовый, ароматерапия, символический, консилиум, завалиться, верю-ю-ть, уша-а-, задок, распознать, фигура, лайза, увертюра, комик, перетерпеть, пинк, покупаться, пробираться, пластинка, ультразвуковой, дубина, пещерный, ледник, ледниковый, прямоходящий, метр-год, марти, смять, невзбить, стиснуть, тренажёр, растоптать, вероятие, поручение, ровный, приобретать, отводиться, карола, отцовство, марта, лагвино, привкус, карри, лагвиновый, угрохать, 40000, головоломка, довольствоваться, амбиция, промах, охотно, амбициозный, карьеристка, бортануль, динозаврище, специфика, шейк, робби, бортанула, марлон, минний, минни-маус, маус, джулия, пересадка, стоматолог-ортодонт, сплюнуть, виллик-банч, наглый, шовинизм, виллик-банч-геллер, геллер-виллик-банч, звездолет, наклонить, расфокусировать, нарожать, дешёвка, условный, алкоголик, смягчать, усыплять, миллнер, резвиться, чича, тюремщик, дэймона, потушить, указательный, тихо-тихо, кофе-латта, прима, кофе-эспрессо, ежемесячный, происки, припрышка, нет-не-мои, кармический, так-с, штив, штить, шекшуальный, ижвинить, шакал, похныкать, попол
ский, советник, коротышка, дора, застенчивый, расшевелить, студент-зверюга, непередаваемый, обезболивать, 12-метр, зря-я-я, нахваливать, валентинка, бли-ин, воз, похвастать, ухитряться, постигать, подлость, множественный, оргазм, голяк, смущённый, замышлять, забастовка, пирожёнка, откидной, беспощадный, барышня, диско-ремикс, похорошеть, заинтересованность, светский, львица, постирам, отрыжка, помиловать, побриться, смягчитель, смягчитель-то, задавить, фотосессия, прогулять, смешанный, лось, чувырло, глазеть, юбервайсс, ниж, трусить, ковыя, хлопковый, юридически, хайтс, кливленд, причмокивать, белочка, дернить, ля-ля, надувной, прохлопать, бродвеять, богемный, извращение, крылышко, бим-бим-бить, бум-бум-бум, непорядок, не-ет, блеск, погоревать, отгоревать, затравленность, обречённый, неизбежный, восклицательный, фот, ефа, ми, зделаля, тепхерить, мошет, скасаль, фаш, пропать, софсема, понятный, мудь, шланг, писуар, мушик, деркатя, сфенеть, содрать, приве-ть, спутник, добыть, кол, итальянка, билетёр, леонард, израильский, армия, 2-х, расплывчатый, антропология, расказывать, лик, насадка, переставлять, выцарапать, степка-растрёпка, растрёпка, оторвой, насыпаний, спроосила, конденсат, столешница, раздобыть, фе, развязать, ба-бе-б, дублёр, дебют, аврора, тефлоновый, скидать, сжиматься, ...

# %%
# c)

unique_docs = {triple[0] for triples in inverted_collection_without_stopwords.values() for triple in triples}
num_of_docs = len(unique_docs)
print(f'Всего документов: {num_of_docs}')

value, results = count_frequency()
print(f"Слова {', '.join(results)} встречаются в {value} документах.")
# Out:
# Всего документов: 165
# Слова как, весь, да, он, просто, ты, на, с, не, мочь, быть, так, у, и, в, я, знать, ну, хотеть, она, что, это, такой, мы, а, тот, мой, нет, если, сказать, этот, о, ещё, но, думать встречаются в 165 документах.

# %%
# d)

def plot_popularity_graph(character, consider_related_words=True):
    related_words = []
    if consider_related_words:
        for word in inverted_collection_with_stopwords:
            if word.startswith(character):
                related_words.append(word)
    else:
        related_words = [character]

    season_to_count = defaultdict(int)
    for word in related_words:
        for triple in inverted_collection_with_stopwords[word]:
            season_to_count[triple[0][10]] += triple[1]

    plt.plot(list(season_to_count.keys()), list(season_to_count.values()))
    return season_to_count

# %%
# 6-й сезон для Чендлера
chandler = plot_popularity_graph('чендлер')

# %%
# 7-й сезон для Моники
monica = plot_popularity_graph('моник')

# %%
# e)

rachel = plot_popularity_graph('рейч')

# %%
phoebe = plot_popularity_graph('фиб')

# %%
joey = plot_popularity_graph('джо', consider_related_words=False)

# %%
ross = plot_popularity_graph('росс', consider_related_words=False)

# %%
chandler_count = sum(chandler.values())
monica_count = sum(monica.values())
rachel_count = sum(rachel.values())
phoebe_count = sum(phoebe.values())
joey_count = sum(joey.values())
ross_count = sum(ross.values())

# %%
# Ross
fig, ax = plt.subplots()
rects = ax.bar(range(6), [chandler_count, monica_count, rachel_count, phoebe_count, joey_count, ross_count], 0.5, color='g')
ax.set_ylabel('Frequency')
ax.set_title('Popularity')
ax.set_xticks(np.add(range(6), 1/50))
ax.set_xticklabels((['Chandler', 'Monica', 'Rachel', 'Phoebe', 'Joey', 'Ross']))

plt.show()
